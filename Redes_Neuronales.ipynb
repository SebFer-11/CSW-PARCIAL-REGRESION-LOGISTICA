# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.style.use("dark_background")

# %% [markdown]
# ## Fase 2: Comprensión de los Datos (Data Understanding)

# %%
## abrir el dataset
df = pd.read_csv('student_dropout_dataset.csv')
df.head()
# Out:
#   student_id  age      region enroll_date  exam_season  courses_enrolled  \
# 0   STU00001   26  Alexandria  2024-01-13            0                 3
# 1   STU00002   23       Amman  2024-05-05            0                 6
# 2   STU00003   17       Dubai  2024-03-12            0                 3
# 3   STU00004   23  Alexandria  2024-12-12            0                 6
# 4   STU00005   20     Baghdad  2024-02-14            0                 5
#
#    completed_assignments  completion_rate  login_frequency  \
# 0                      5           0.3571             5.29
# 1                      0           0.0000             0.84
# 2                      1           0.0435             1.79
# 3                     13           0.4396             0.78
# 4                      5           0.2078             0.92
#
#    last_activity_days_ago  forum_posts_count  dropout_score  label  \
# 0                      10                  5         0.1064      0
# 1                       7                  0         0.6627      1
# 2                      36                  0         0.7299      1
# 3                       9                  0         0.5315      1
# 4                      11                  0         0.7904      1
#
#    label_multiclass label_name
# 0                 0     active
# 1                 2    dropped
# 2                 2    dropped
# 3                 1    at-risk
# 4                 2    dropped

# %%
## eliminamso las columnas que no nescesitamos 
df = df.drop(columns=[
    'student_id',
    'dropout_score',
    'label_multiclass',
    'label_name', 
    'region' , 
    'enroll_date'
])
df = df.rename(columns={'label':'target'})

# %%
## columnas  y tipos de datos
df.dtypes
# Out:
# age                         int64
# exam_season                 int64
# courses_enrolled            int64
# completed_assignments       int64
# completion_rate           float64
# login_frequency           float64
# last_activity_days_ago      int64
# forum_posts_count           int64
# target                      int64
# dtype: object

# %%
corre['target']
# Out:
# age                      -0.018860
# exam_season               0.085564
# courses_enrolled          0.002108
# completed_assignments    -0.591613
# completion_rate          -0.727738
# login_frequency          -0.711562
# last_activity_days_ago    0.085701
# forum_posts_count        -0.634606
# target                    1.000000
# Name: target, dtype: float64

# %%
## matris de correlacion de las caracteristicas 
corre = df[df.select_dtypes(include='number').columns].corr()
plt.figure(figsize=(12  , 8))
sns.heatmap(corre , annot=True  , vmax=1   , vmin=-1 ,  cmap="coolwarm" )
plt.show()

# %%
df.describe()
# Out:
#                age  exam_season  courses_enrolled  completed_assignments  \
# count  5000.000000  5000.000000       5000.000000            5000.000000
# mean     23.736600     0.094000          3.999400               5.188400
# std       4.583211     0.291858          1.997348               6.109466
# min      17.000000     0.000000          1.000000               0.000000
# 25%      20.000000     0.000000          2.000000               1.000000
# 50%      24.000000     0.000000          4.000000               3.000000
# 75%      27.000000     0.000000          6.000000               7.000000
# max      40.000000     1.000000          7.000000              35.000000
#
#        completion_rate  login_frequency  last_activity_days_ago  \
# count      5000.000000      5000.000000               5000.0000
# mean          0.260985         3.453820                  9.3564
# std           0.249010         3.248316                  9.4361
# min           0.000000         0.100000                  1.0000
# 25%           0.053900         0.980000                  2.0000
# 50%           0.206700         2.440000                  6.0000
# 75%           0.389025         4.942500                 13.0000
# max           1.000000        14.000000                 70.0000
#
#        forum_posts_count       target
# count        5000.000000  5000.000000
# mean            4.212200     0.659200
# std             4.270131     0.474026
# min             0.000000     0.000000
# 25%             1.000000     0.000000
# 50%             3.000000     1.000000
# 75%             6.000000     1.000000
# max            24.000000     1.000000

# %%
##  relaciones bivariadas entre las variables numéricas del dataset.
cols = ['completion_rate','login_frequency','forum_posts_count','target']
sns.pairplot(df[cols], hue='target')

# %%
## deteccion de valore atipicos com box plot
plt.figure(figsize=(12,6))
sns.boxplot(data=df.select_dtypes(include='number'))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Fase 3: Preparación de los Datos (Data Preparation)

# %%
### ver si hay datos nulos
missing_info = pd.DataFrame({
    "nulos": df.isnull().sum(),
     "no_nulos": df.notnull().sum(),
     "porcentaje_nulos": df.isnull().mean() * 100,
    "porcentaje_no_nulos": df.notnull().mean() * 100
})
missing_info
# Out:
#                         nulos  no_nulos  porcentaje_nulos  porcentaje_no_nulos
# age                         0      5000               0.0                100.0
# exam_season                 0      5000               0.0                100.0
# courses_enrolled            0      5000               0.0                100.0
# completed_assignments       0      5000               0.0                100.0
# completion_rate             0      5000               0.0                100.0
# login_frequency             0      5000               0.0                100.0
# last_activity_days_ago      0      5000               0.0                100.0
# forum_posts_count           0      5000               0.0                100.0
# target                      0      5000               0.0                100.0

# %%
## imputacion de datos 
def imputacion (name_column):
    mean = df[name_column].mean()
    df[name_column].replace(np.nan , mean , inplace=True)
## esta funciona solo funciona para valores columnas numericas en caso que sean categoricas se aplica la moda

# %%
##seleccion de variables independientes y variable objetivo
columnas = ['completion_rate',
        'login_frequency',
        'forum_posts_count',
        'completed_assignments',
        'last_activity_days_ago' ]

x_data = df[columnas]

y_data = df['target']

# %%
## separa los datos en trin y test 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(
    x_data, y_data, test_size=0.2, stratify=y_data, random_state=42
)

## estandarisar los datos 
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
df['target'].value_counts(normalize=True)
# Out:
# target
# 1    0.6592
# 0    0.3408
# Name: proportion, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight='balanced')

# %% [markdown]
# ## Fase 4: Modelado (Modeling) Modelado (MLP)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()

# Capa de entrada + capa oculta
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.3))

# Segunda capa oculta
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

# Capa de salida
model.add(Dense(1, activation='sigmoid')) 

## Configuración
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['Recall']
)

## Entrenamiento del modelo
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# C:\Users\mgiba\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9129 - loss: 0.3749 - val_Recall: 0.9220 - val_loss: 0.2574
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9223 - loss: 0.2494 - val_Recall: 0.9240 - val_loss: 0.2479
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9303 - loss: 0.2391 - val_Recall: 0.9162 - val_loss: 0.2365
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9275 - loss: 0.2294 - val_Recall: 0.9337 - val_loss: 0.2321
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9313 - loss: 0.2267 - val_Recall: 0.9376 - val_loss: 0.2284
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9327 - loss: 0.2236 - val_Recall: 0.9357 - val_loss: 0.2307
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9364 - loss: 0.2243 - val_Recall: 0.9318 - val_loss: 0.2247
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9303 - loss: 0.2198 - val_Recall: 0.9298 - val_loss: 0.2223
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9374 - loss: 0.2172 - val_Recall: 0.9220 - val_loss: 0.2234
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9322 - loss: 0.2215 - val_Recall: 0.9493 - val_loss: 0.2225
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9402 - loss: 0.2194 - val_Recall: 0.9298 - val_loss: 0.2217
# Epoch 12/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9341 - loss: 0.2140 - val_Recall: 0.9435 - val_loss: 0.2192
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9388 - loss: 0.2166 - val_Recall: 0.9259 - val_loss: 0.2167
# Epoch 14/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9411 - loss: 0.2103 - val_Recall: 0.9454 - val_loss: 0.2202
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9435 - loss: 0.2129 - val_Recall: 0.9357 - val_loss: 0.2177
# Epoch 16/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9454 - loss: 0.2124 - val_Recall: 0.9454 - val_loss: 0.2169
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9473 - loss: 0.2157 - val_Recall: 0.9376 - val_loss: 0.2145
# Epoch 18/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9416 - loss: 0.2117 - val_Recall: 0.9415 - val_loss: 0.2152
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Recall: 0.9468 - loss: 0.2084 - val_Recall: 0.9415 - val_loss: 0.2149
# Epoch 20/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9411 - loss: 0.2093 - val_Recall: 0.9376 - val_loss: 0.2131
# Epoch 21/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9459 - loss: 0.2072 - val_Recall: 0.9337 - val_loss: 0.2133
# Epoch 22/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9397 - loss: 0.2085 - val_Recall: 0.9435 - val_loss: 0.2143
# Epoch 23/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9482 - loss: 0.2077 - val_Recall: 0.9357 - val_loss: 0.2115
# Epoch 24/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9487 - loss: 0.2061 - val_Recall: 0.9454 - val_loss: 0.2121
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9444 - loss: 0.2086 - val_Recall: 0.9376 - val_loss: 0.2104
# Epoch 26/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9468 - loss: 0.2071 - val_Recall: 0.9435 - val_loss: 0.2093
# Epoch 27/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9440 - loss: 0.2063 - val_Recall: 0.9435 - val_loss: 0.2094
# Epoch 28/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9506 - loss: 0.1994 - val_Recall: 0.9396 - val_loss: 0.2105
# Epoch 29/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9454 - loss: 0.2055 - val_Recall: 0.9415 - val_loss: 0.2093
# Epoch 30/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9501 - loss: 0.2004 - val_Recall: 0.9415 - val_loss: 0.2085
# Epoch 31/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9510 - loss: 0.2010 - val_Recall: 0.9532 - val_loss: 0.2096
# Epoch 32/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9492 - loss: 0.2054 - val_Recall: 0.9454 - val_loss: 0.2083
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9534 - loss: 0.2011 - val_Recall: 0.9454 - val_loss: 0.2084
# Epoch 34/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9468 - loss: 0.2018 - val_Recall: 0.9571 - val_loss: 0.2107
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9553 - loss: 0.2021 - val_Recall: 0.9513 - val_loss: 0.2091
# Epoch 36/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9482 - loss: 0.2040 - val_Recall: 0.9474 - val_loss: 0.2071
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9468 - loss: 0.2026 - val_Recall: 0.9415 - val_loss: 0.2083
# Epoch 38/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9473 - loss: 0.1981 - val_Recall: 0.9474 - val_loss: 0.2063
# Epoch 39/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9482 - loss: 0.1970 - val_Recall: 0.9493 - val_loss: 0.2074
# Epoch 40/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9520 - loss: 0.1960 - val_Recall: 0.9474 - val_loss: 0.2036
# Epoch 41/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9515 - loss: 0.1989 - val_Recall: 0.9493 - val_loss: 0.2042
# Epoch 42/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9534 - loss: 0.1936 - val_Recall: 0.9513 - val_loss: 0.2039
# Epoch 43/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9529 - loss: 0.1976 - val_Recall: 0.9513 - val_loss: 0.2059
# Epoch 44/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9520 - loss: 0.1964 - val_Recall: 0.9532 - val_loss: 0.2051
# Epoch 45/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9515 - loss: 0.1972 - val_Recall: 0.9513 - val_loss: 0.2054
# Epoch 46/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9506 - loss: 0.1952 - val_Recall: 0.9493 - val_loss: 0.2058
# Epoch 47/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9572 - loss: 0.1920 - val_Recall: 0.9474 - val_loss: 0.2050
# Epoch 48/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9520 - loss: 0.1922 - val_Recall: 0.9474 - val_loss: 0.2043
# Epoch 49/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9520 - loss: 0.1923 - val_Recall: 0.9513 - val_loss: 0.2053
# Epoch 50/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - Recall: 0.9543 - loss: 0.1939 - val_Recall: 0.9454 - val_loss: 0.2052

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Curva de aprendizaje (Loss vs Epochs)")
plt.legend()
plt.show()

# %% [markdown]
# ## Fase 5: Evaluación (MLP)

# %%
## Predicciones del modelo
y_prob = model.predict(X_test).ravel()
y_pred = (y_prob > 0.5).astype(int)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Riesgo (0)', 'Riesgo (1)'],
            yticklabels=['No Riesgo (0)', 'Riesgo (1)'])

plt.xlabel('Predicción')
plt.ylabel('Real')
plt.title('Matriz de Confusión - MLP')
plt.show()

# %%
## recall
from sklearn.metrics import recall_score

recall = recall_score(y_test, y_pred)
print("Recall:", recall)
# Out:
# Recall: 0.9499241274658573

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall_vals, thresholds = precision_recall_curve(y_test, y_prob)

plt.plot(recall_vals, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall (MLP)")
plt.show()
